# %% [markdown]
# <a href="https://colab.research.google.com/github/KRiver28/prac/blob/master/WEBTOON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# !pip install lxml
#bs4 = beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://comic.naver.com/webtoon/weekday'
res = requests.get(url)
res.raise_for_status()

# %%
soup =BeautifulSoup(res.text,'lxml')
cartoons = soup.find_all(
    'a',
    attrs={'class':'title'}
)

# %%
for cartoon in cartoons:
  print(cartoon.get_text())
# Out:
# 쇼미더럭키짱!
# 참교육
# 신의 탑
# 2022 서브병에 빠지다!
# 퀘스트지상주의
# 소녀의 세계
# 장씨세가 호위무사
# 백수세끼
# 팔이피플
# 앵무살수
# 만렙돌파
# 잔불의 기사
# 요리GO
# 리턴 투 플레이어
# 더블클릭
# 히어로메이커
# 칼가는 소녀
# 물어보는 사이
# 똑 닮은 딸
# 별을 쫓는 소년들
# 결혼생활 그림일기
# 평범한 8반
# 황제와의 하룻밤
# 꼬리잡기
# 신군
# 찌질하지만 로맨스는 하고 싶어
# 오로지 오로라
# 꿈의 기업
# 아는 여자애
# 이별 후 사내 결혼
# 제왕: 빛과 그림자
# 아, 쫌 참으세요 영주님!
# 나만의 고막남친
# 싸이코 리벤지
# 장난감
# 악녀 18세 공략기
# 레지나레나 - 용서받지 못한 그대에게
# 오빠집이 비어서
# 이제야 연애
# 와이키키 뱀파이어
# 말박왕
# 바퀴
# 순정말고 순종
# 또다시, 계약 부부
# 원작은 완결난 지 한참 됐습니다만
# 최후의 금빛아이
# 야생천사 보호구역
# 왕따협상
# 달로 만든 아이
# 원하는 건 너 하나
# 모스크바의 여명
# 이중첩자
# 홍천기
# 하루의 하루
# 중독연구소
# 마지막 지수
# 개밥 먹는 남자
# 그림자 신부
# 역주행!
# 바로 보지 않는
# 백호랑
# 남주서치
# 트리거
# 모락모락 왕세자님
# 사막에 핀 달
# 헬로맨스
# 보살님이 캐리해!
# 결백한 사람은 없다
# 슈퍼스타 천대리
# 기사님을 지켜줘
# 쇼미더럭키짱!
# 김부장
# 여신강림
# 2022 서브병에 빠지다!
# 1을 줄게
# 한림체육관
# 내가 키운 S급들
# 사신소년
# 하루만 네가 되고 싶어
# 중증외상센터 : 골든 아워
# 달콤살벌한 부부
# 신도림
# 니나의 마법서랍
# 엽총소년
# 용사가 돌아왔다
# 집이 없어
# 삼국지톡
# 랜덤채팅의 그녀!
# 헬58
# 하북팽가 막내아들
# 소극적 인간
# 원주민 공포만화
# 덴큐
# 윌유메리미
# 애옹식당
# 몬스터
# 위아더좀비
# 택배 왔습니다
# 한입만!
# 하우스키퍼
# 또 다른 사랑
# 빌런투킬
# ...

# %%
url = 'https://comic.naver.com/webtoon/list?titleId=748105&weekday=thu'
res = requests.get(url)
res.raise_for_status()

# %%
soup =BeautifulSoup(res.text,'lxml')
cartoons2 = soup.find_all(
    'td',
    attrs={'class':'title'}
)

# %%
type(cartoons2)
# Out:
# bs4.element.ResultSet

# %%
cartoons2
# Out:
# [<td class="title">
#  <a href="/webtoon/detail?titleId=748105&amp;no=147&amp;weekday=thu" onclick="nclk_v2(event,'lst.title','748105','147')">시즌2 44화 신년 맞이 스케일링</a>
#  </td>, <td class="title">
#  <a href="/webtoon/detail?titleId=748105&amp;no=146&amp;weekday=thu" onclick="nclk_v2(event,'lst.title','748105','146')">시즌2 43화 부모님 가르쳐드리기</a>
#  </td>, <td class="title">
#  <a href="/webtoon/detail?titleId=748105&amp;no=145&amp;weekday=thu" onclick="nclk_v2(event,'lst.title','748105','145')">시즌2 42화 시간제 캠핑</a>
#  </td>, <td class="title">
#  <a href="/webtoon/detail?titleId=748105&amp;no=144&amp;weekday=thu" onclick="nclk_v2(event,'lst.title','748105','144')">시즌2 41화 우리 집 산타</a>
#  </td>, <td class="title">
#  <a href="/webtoon/detail?titleId=748105&amp;no=143&amp;weekday=thu" onclick="nclk_v2(event,'lst.title','748105','143')">시즌2 40화 깐부</a>
#  </td>, <td class="title">
# ...

# %%
ratings=soup.find_all('div', attrs={'class':'rating_type'})

for rating in ratings:
  rate =float(rating.find('strong').get_text())
  sum+=rate

rate
# Out:
# 9.98
